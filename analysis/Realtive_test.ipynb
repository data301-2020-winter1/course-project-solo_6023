# %%
from scripts import m2

df = m2.load_data("/Users/Mason/cosc301/course-project-solo_6023/data/raw/all_alpha_20.csv")
df
# Out:
#            Model  Displacement  # of Cylinders Transmission Drive  \
# 0      ACURA ILX           2.4             4.0        AMS-8   2WD
# 1      ACURA ILX           2.4             4.0        AMS-8   2WD
# 2      ACURA MDX           3.0             6.0        AMS-7   4WD
# 3      ACURA MDX           3.0             6.0        AMS-7   4WD
# 4      ACURA MDX           3.5             6.0   SemiAuto-9   2WD
# ...          ...           ...             ...          ...   ...
# 2518  VOLVO XC90           2.0             4.0   SemiAuto-8   4WD
# 2519  VOLVO XC90           2.0             4.0   SemiAuto-8   4WD
# 2520  VOLVO XC90           2.0             4.0   SemiAuto-8   4WD
# 2521  VOLVO XC90           2.0             4.0   SemiAuto-8   4WD
# 2522  VOLVO XC90           2.0             4.0   SemiAuto-8   4WD
#
#                       Fuel          Type City MPG Highway MPG Combined MPG
# 0                 Gasoline     small car       24          34           28
# ...
